# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("C:\\Users\\Karth\\Downloads\\Lemonade2016-2.csv")

# %%
df
# Out:
#          Date Location  Lemon  Orange  Temperature  Leaflets  Price
# 0    7/1/2016     Park     97      67           70      90.0   0.25
# 1    7/2/2016     Park     98      67           72      90.0   0.25
# 2    7/3/2016     Park    110      77           71     104.0   0.25
# 3    7/4/2016    Beach    134      99           76      98.0   0.25
# 4    7/5/2016    Beach    159     118           78     135.0   0.25
# 5    7/6/2016    Beach    103      69           82      90.0   0.25
# 6    7/6/2016    Beach    103      69           82      90.0   0.25
# 7    7/7/2016    Beach    143     101           81     135.0   0.25
# 8         NaN    Beach    123      86           82     113.0   0.25
# 9    7/9/2016    Beach    134      95           80     126.0   0.25
# 10  7/10/2016    Beach    140      98           82     131.0   0.25
# 11  7/11/2016    Beach    162     120           83     135.0   0.25
# 12  7/12/2016    Beach    130      95           84      99.0   0.25
# ...

# %%
df.iloc[8,0] = '7/8/2016'

# %%
df.loc[20,'Leaflets']
# Out:
# nan

# %%
df['Leaflets'].notnull()
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9      True
# 10     True
# 11     True
# 12     True
# 13     True
# 14     True
# 15     True
# 16     True
# 17     True
# 18     True
# 19     True
# 20    False
# 21     True
# 22     True
# 23     True
# 24     True
# 25     True
# 26     True
# 27     True
# 28     True
# 29     True
# 30     True
# 31     True
# Name: Leaflets, dtype: bool

# %%
df['Leaflets'].fillna(round(df['Leaflets'].mean(),0))
df
# Out:
#          Date Location  Lemon  Orange  Temperature  Leaflets  Price
# 0    7/1/2016     Park     97      67           70      90.0   0.25
# 1    7/2/2016     Park     98      67           72      90.0   0.25
# 2    7/3/2016     Park    110      77           71     104.0   0.25
# 3    7/4/2016    Beach    134      99           76      98.0   0.25
# 4    7/5/2016    Beach    159     118           78     135.0   0.25
# 5    7/6/2016    Beach    103      69           82      90.0   0.25
# 7    7/7/2016    Beach    143     101           81     135.0   0.25
# 8    7/8/2016    Beach    123      86           82     113.0   0.25
# 9    7/9/2016    Beach    134      95           80     126.0   0.25
# 10  7/10/2016    Beach    140      98           82     131.0   0.25
# 11  7/11/2016    Beach    162     120           83     135.0   0.25
# 12  7/12/2016    Beach    130      95           84      99.0   0.25
# 13  7/13/2016    Beach    109      75           77      99.0   0.25
# ...

# %%
df['Leaflets'].mean()
# Out:
# 108.54838709677419

# %%
df.iloc[20,5] = round(df['Leaflets'].mean(),0)
df
# Out:
#          Date Location  Lemon  Orange  Temperature  Leaflets  Price
# 0    7/1/2016     Park     97      67           70      90.0   0.25
# 1    7/2/2016     Park     98      67           72      90.0   0.25
# 2    7/3/2016     Park    110      77           71     104.0   0.25
# 3    7/4/2016    Beach    134      99           76      98.0   0.25
# 4    7/5/2016    Beach    159     118           78     135.0   0.25
# 5    7/6/2016    Beach    103      69           82      90.0   0.25
# 6    7/6/2016    Beach    103      69           82      90.0   0.25
# 7    7/7/2016    Beach    143     101           81     135.0   0.25
# 8    7/8/2016    Beach    123      86           82     113.0   0.25
# 9    7/9/2016    Beach    134      95           80     126.0   0.25
# 10  7/10/2016    Beach    140      98           82     131.0   0.25
# 11  7/11/2016    Beach    162     120           83     135.0   0.25
# 12  7/12/2016    Beach    130      95           84      99.0   0.25
# ...

# %%
df = df.drop_duplicates()
df
# Out:
#          Date Location  Lemon  Orange  Temperature  Leaflets  Price
# 0    7/1/2016     Park     97      67           70      90.0   0.25
# 1    7/2/2016     Park     98      67           72      90.0   0.25
# 2    7/3/2016     Park    110      77           71     104.0   0.25
# 3    7/4/2016    Beach    134      99           76      98.0   0.25
# 4    7/5/2016    Beach    159     118           78     135.0   0.25
# 5    7/6/2016    Beach    103      69           82      90.0   0.25
# 7    7/7/2016    Beach    143     101           81     135.0   0.25
# 8    7/8/2016    Beach    123      86           82     113.0   0.25
# 9    7/9/2016    Beach    134      95           80     126.0   0.25
# 10  7/10/2016    Beach    140      98           82     131.0   0.25
# 11  7/11/2016    Beach    162     120           83     135.0   0.25
# 12  7/12/2016    Beach    130      95           84      99.0   0.25
# 13  7/13/2016    Beach    109      75           77      99.0   0.25
# ...

# %%
df=df.reset_index(drop = True)
df
# Out:
#          Date Location  Lemon  Orange  Temperature  Leaflets  Price
# 0    7/1/2016     Park     97      67           70      90.0   0.25
# 1    7/2/2016     Park     98      67           72      90.0   0.25
# 2    7/3/2016     Park    110      77           71     104.0   0.25
# 3    7/4/2016    Beach    134      99           76      98.0   0.25
# 4    7/5/2016    Beach    159     118           78     135.0   0.25
# 5    7/6/2016    Beach    103      69           82      90.0   0.25
# 6    7/7/2016    Beach    143     101           81     135.0   0.25
# 7    7/8/2016    Beach    123      86           82     113.0   0.25
# 8    7/9/2016    Beach    134      95           80     126.0   0.25
# 9   7/10/2016    Beach    140      98           82     131.0   0.25
# 10  7/11/2016    Beach    162     120           83     135.0   0.25
# 11  7/12/2016    Beach    130      95           84      99.0   0.25
# 12  7/13/2016    Beach    109      75           77      99.0   0.25
# ...

# %%
df['Sales'] = df['Lemon'] + df['Orange']
df['Revenue'] = df['Sales'] * df['Price']
df
dfTemp75 = df.loc[df['Temperature']>75,:]
dfTemp75
dfTemp75.boxplot(by ='Location', column = 'Sales')

df.plot.scatter(x="Leaflets", y = "Sales")
plt.hist(df['Revenue'], bins =10)
plt.title("Revenue Histogram")
plt.show()

df.boxplot(by ='Location', column ='Sales')
# Out:
# C:\Users\Karth\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:57: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)

# %%
import seaborn as sns
#ax = sns.boxplot(x="Location",y="Sales",data=df, hue = "")

 #ax = sns.boxplot(x="Location",y="Sales",data=df, hue = "Location", pallete = "Set3")

sns.pairplot(df, kind = "reg")
sns.pairplot(df, hue = "Location")
